# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('monthly-milk-production.csv', sep=';', index_col=['milk'], parse_dates=['month'], dayfirst=True)
data.head()
# Out:
#           month
# milk
# 589  1962-01-01
# 561  1962-02-01
# 640  1962-03-01
# 656  1962-04-01
# 727  1962-05-01

# %%
sns.lineplot(x=data.month.values, y=data.index.values);

# %%
data['month']
# Out:
# 0     1962-01-01
# 1     1962-02-01
# 2     1962-03-01
# 3     1962-04-01
# 4     1962-05-01
#          ...
# 163   1975-08-01
# 164   1975-09-01
# 165   1975-10-01
# 166   1975-11-01
# 167   1975-12-01
# Name: month, Length: 168, dtype: datetime64[ns]

# %%
import statsmodels.api as sm

round(sm.tsa.stattools.adfuller(data)[1], 2)
# Out:
# 0.93

# %%
from calendar import monthrange
